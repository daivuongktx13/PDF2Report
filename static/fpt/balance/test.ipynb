# %%
import pandas as pd

# %%
data = pd.read_csv("image5.xlsx")

# %%
data
# Out:
#     Unnamed: 0                                            0         1  \
# 0            0                                          NaN       NaN
# 1            1                                      TÀI SẢN        MS
# 2            2                          A. TÀI SẢN NGẮN HẠN       100
# 3            3        I. Tiền và các khoản tương đương tiền       110
# 4            4                                      1: Tiền       111
# 5            5                2. Các khoản tương đương tiền       112
# 6            6                II. Đầu tư tài chính ngắn hạn       120
# 7            7           1. Đầu tư nắm giữ đến ngày đáo hạn       123
# 8            8             I11. Các khoản phải thu ngắn hạn       130
# 9            9          1. Phải thu ngắn hạn của khách hàng       131
# 10          10          2. Trả trước cho người bán ngắn hạn       132
# 11          11                    3. Phải thu ngắn hạn khác       136
# ...
